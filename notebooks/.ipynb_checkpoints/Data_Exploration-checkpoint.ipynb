# %% [markdown]
# ### IMPORT

# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib as plt

# %%
pd.set_option("display.max_columns",100)

# %%
### working with date : 
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %% [markdown]
# ### LOAD DATASET

# %%
### a function to load (and concatene) informations from Parc_XX.csv
def create_df_parc_data(list_num_parc,list_date_parc):
    df_parc_data = pd.DataFrame()
    for num_parc in list_num_parc:
        for date_parc in list_date_parc:
            df_parc_data = df_parc_data.append(pd.read_csv("../data/Parc%s_%s.csv"%(num_parc,date_parc),sep=";",decimal=','),ignore_index=True)
    df_parc_data["Date"] = pd.to_datetime(df_parc_data["Date"],format = "%d/%m/%Y %H:%M")
    return df_parc_data

# %%
list_num_parc = [1,2,3]
list_date_parc = ["2015","2016","2017"]

# %%
df_parc_data = create_df_parc_data(list_num_parc,list_date_parc)

# %%
print (df_parc_data.shape)
df_parc_data.columns
# Out:
# (13226400, 17)
# Index([u'Catégorie', u'Date', u'Eolienne', u'Etat', u'Figee',
#        u'Fonctionnement', u'GridBrut', u'GridOK', u'Manquante', u'P',
#        u'Production', u'State', u'Température génératrice', u'TurbBrut',
#        u'TurbOK', u'Vent', u'Vitesse génératrice'],
#       dtype='object')

# %%
df_parc_data["Fonctionnement"].value_counts()
# Out:
# 1    12910771
# 0      315629
# Name: Fonctionnement, dtype: int64

# %% [markdown]
# ##### we create the Production_mean_hour varaible : mean production per hour

# %%
### we create an ident for each hour "Date_hour_int"
df_parc_data["Date_hour_int"] = df_parc_data["Date"].dt.year*10**6  + df_parc_data["Date"].dt.month*10**4 +\
df_parc_data["Date"].dt.day*10**2 + df_parc_data["Date"].dt.hour
#### we create a dataframe with "production_mean_hour" value for each Eolienne*date_hour_int
df_product_mean = df_parc_data[df_parc_data["Fonctionnement"]==1].groupby(["Eolienne","Date_hour_int"])["Production"]\
                            .mean().reset_index().rename(columns={"Production":"Production_mean_hour"})

##### we add this value in the initial dataset "df_parc_data"
df_parc_data = pd.merge(df_parc_data,df_product_mean,on=["Eolienne","Date_hour_int"],how="left")

# %%
df_parc_data.head(3)
# Out:
#                                     Catégorie                Date Eolienne  \
# 0  Fonctionnement > Correct > Rien à signaler 2015-01-01 00:00:00    Turb3
# 1  Fonctionnement > Correct > Rien à signaler 2015-01-01 00:01:00    Turb3
# 2  Fonctionnement > Correct > Rien à signaler 2015-01-01 00:02:00    Turb3
#
#   Etat  Figee  Fonctionnement  GridBrut  GridOK  Manquante     P  Production  \
# 0  Run    0.0               1   40276.0     0.0        0.0 -1.02        52.7
# 1  Run    0.0               1   40276.0     0.0        0.0 -0.53        79.9
# 2  Run    0.0               1   40276.0     0.0        0.0 -0.61        93.9
#
#    State  Température génératrice  TurbBrut  TurbOK  Vent  \
# 0      3                     45.0   40161.0     0.0  3.84
# 1      3                     45.0   40161.0     0.0  4.11
# 2      3                     45.0   40161.0     0.0  3.70
#
#    Vitesse génératrice  Date_hour_int  Production_mean_hour
# 0              1281.17     2015010100            121.923333
# 1              1258.79     2015010100            121.923333
# 2              1250.21     2015010100            121.923333

# %% [markdown]
# #### EXAMPLE VISUALISATION

# %%
eolienne_C ="Turb3" # we choose one wind turbine
date_VIZ_C=datetime(2015,3,1) # we choose one date
list_col_to_create_rolling = ["Vent","Production"]

# %%
df_all_VIZ = df_parc_data[(df_parc_data["Fonctionnement"]==1)&(df_parc_data["Eolienne"]==eolienne_C)].copy()
### for the visualisation, we create create the 1-hour moving avarage value (rolling_60). 
df_all_VIZ[["%s_rolling_60"%x for x in list_col_to_create_rolling]] = df_all_VIZ[list_col_to_create_rolling].rolling(window=60,min_periods=1).mean()
list_col_VIZ = ["Production","Production_mean_hour","Vent"]+["%s_rolling_60"%x for x in list_col_to_create_rolling]
df_VIZ = df_all_VIZ[(df_all_VIZ["Date"]>=date_VIZ_C)&(df_all_VIZ["Date"]<date_VIZ_C+relativedelta(days=3))].set_index("Date")[list_col_VIZ]

# %%
df_VIZ.head(3)
# Out:
#                      Production  Production_mean_hour  Vent  Vent_rolling_60  \
# Date
# 2015-03-01 00:00:00     1343.87             1760.3295  9.29        10.367500
# 2015-03-01 00:01:00     1280.38             1760.3295  9.98        10.365833
# 2015-03-01 00:02:00     1752.90             1760.3295  7.40        10.306500
#
#                      Production_rolling_60
# Date
# 2015-03-01 00:00:00            1753.598167
# 2015-03-01 00:01:00            1745.156500
# 2015-03-01 00:02:00            1745.875000

# %%
df_VIZ["Production_mean_hour"].fillna(method="bfill",inplace=True)

# %%
df_VIZ[["Production","Production_mean_hour","Production_rolling_60"]].plot(figsize=(16,4))

# %% [markdown]
# #### With wind

# %%
df_VIZ[["Vent_rolling_60","Production_rolling_60"]].plot(secondary_y='Vent_rolling_60',figsize=(16,4))

# %% [markdown]
# ####  WEATHER's DATASET

# %%
### a function to load (and concatene) informations from PrevMeteo_GrilleXX.xlsx
def create_df_meteo_from_list_grille(list_grille):
    df_meteo  = pd.DataFrame()
    for grille_C in list_grille:
        df_meteo_tmp =  pd.read_excel('../data/PrevMeteo_Grille%s.xlsx'%(grille_C),sep=';')
        df_meteo_tmp["grille"] = grille_C
        df_meteo = df_meteo.append(df_meteo_tmp,ignore_index=True)
    df_meteo["date"] = pd.to_datetime(df_meteo["date"],format = "%Y-%m-%d %H:%M:%S")
    df_meteo.rename(columns= {"date":"Date"},inplace=True)
    return df_meteo

# %%
## for weather's data,we can take the value of 16 different "grille" 
list_grille= range(1,17)
##for this example notebook, we will only take one "grille" (=9) 
df_meteo = create_df_meteo_from_list_grille(list_grille=[9])

# %%
df_meteo.shape
# Out:
# (58450, 36)

# %%
df_meteo.columns
# Out:
# Index([   u'Date',  u'fc_hor',      u'RS',    u'CAPE',      u'SP',      u'CP',
#            u'BLD',    u'SSHF',    u'SLHF',     u'MSL',     u'BLH',     u'TCC',
#            u'U10',     u'V10',      u'T2',      u'D2',    u'SSRD',    u'STRD',
#            u'SSR',     u'STR',     u'TSR',     u'LCC',     u'MCC',     u'HCC',
#           u'TSRC',    u'SSRC',    u'STRC',      u'TP',      u'FA',    u'U100',
#           u'V100', u'vit_100',  u'vit_10', u'dir_100',  u'dir_10',  u'grille'],
#       dtype='object')

# %%
df_meteo.tail()
# Out:
#                      Date  fc_hor          RS      CAPE           SP  \
# 58445 2017-04-16 20:00:00      68  26149068.0  0.000000  101590.0000
# 58446 2017-04-16 21:00:00      69  26149068.0  0.000000  101574.1250
# 58447 2017-04-16 22:00:00      70  26149068.0  0.000000  101542.9375
# 58448 2017-04-16 23:00:00      71  26149068.0  1.261719  101503.2500
# 58449 2017-04-17 00:00:00      72  26149068.0  6.984863  101454.3750
#
#              CP       BLD       SSHF      SLHF           MSL         BLH  \
# 58445  0.001052  1.216649  25.626667 -6.204444  102325.03125  473.472321
# 58446  0.001052  2.284219  29.382223 -3.208889  102309.50000  424.312469
# 58447  0.001052  2.357309  30.035555 -3.182222  102278.21875  423.143585
# 58448  0.001052  2.289253  25.862223 -4.697778  102238.06250  439.622528
# 58449  0.001052  2.361719  11.448889 -7.035555  102187.43750  567.963623
#
#             TCC       U10       V10        T2        D2  SSRD        STRD  \
# 58445  0.656982  3.630444  0.743793  8.365137  5.346338 -0.04  297.799988
# 58446  0.345856  3.450853  1.312599  8.043604  5.771142  0.00  291.471100
# 58447  0.960724  3.664190  1.628366  7.972070  5.403955  0.00  291.768890
# 58448  1.000000  3.670717  1.780635  8.252832  5.464746  0.00  306.364441
# 58449  1.000000  3.823283  2.040882  9.209375  6.013818  0.00  346.822235
#
#        SSR        STR  TSR       LCC       MCC       HCC  TSRC  SSRC  \
# 58445  0.0 -52.204445  0.0  0.390015  0.400482  0.208832   0.0   0.0
# 58446  0.0 -56.346668  0.0  0.102783  0.302917  0.054443   0.0   0.0
# 58447  0.0 -54.551109  0.0  0.820557  0.524689  0.636566   0.0   0.0
# 58448  0.0 -42.119999  0.0  1.000000  0.881134  0.757996   0.0   0.0
# 58449  0.0  -9.071111  0.0  1.000000  0.936310  0.004333   0.0   0.0
#
#             STRC            TP        FA      U100      V100   vit_100  \
# 58445 -82.862221  0.000000e+00  0.203704  6.992155  0.705566  7.027664
# 58446 -79.462219  0.000000e+00  0.203702  6.960267  1.711334  7.167564
# 58447 -76.826668  9.536743e-07  0.203700  7.269725  2.243958  7.608170
# 58448 -75.040001  9.536743e-07  0.203698  7.126820  2.500241  7.552666
# 58449 -74.235558  2.002716e-05  0.203695  6.799860  2.847061  7.371828
#
#          vit_10     dir_100      dir_10  grille
# 58445  3.705853  264.237885  258.421661       9
# 58446  3.692060  256.186584  249.174713       9
# 58447  4.009722  252.846039  246.039642       9
# 58448  4.079807  250.668030  244.122345       9
# 58449  4.333900  247.281219  241.906540       9

# %%
### the aim of this challenge is to predict the Production for tomorrow. 
# so, we keep only forecast (fc_hor) between 24h and 47h (Tomorrow's Forecast)
df_meteo = df_meteo[(df_meteo["fc_hor"]>=24)&(df_meteo["fc_hor"]<=47)].copy()

# %% [markdown]
# ### we create df_all (concatenation of train and test)
# it's the dataset for the model.

# %%
### we keep only one row per hour (minute =0)
### we keep only one row where the wind turbine is working (Fonctionnement =1)
### we keep only usefull columns
list_col_parc_data_to_keep = ["Date","Eolienne","Production","Fonctionnement","Production_mean_hour"]
df_all = df_parc_data[(df_parc_data["Date"].dt.minute==0)&(df_parc_data["Fonctionnement"]==1)]\
[list_col_parc_data_to_keep].copy()

# %%
print (df_all.shape)
df_all.head(3)
# Out:
# (215158, 5)
#                    Date Eolienne  Production  Fonctionnement  \
# 0   2015-01-01 00:00:00    Turb3        52.7               1
# 60  2015-01-01 01:00:00    Turb3       180.0               1
# 120 2015-01-01 02:00:00    Turb3       156.5               1
#
#      Production_mean_hour
# 0              121.923333
# 60             210.081667
# 120            255.016667

# %% [markdown]
# #### we add weather's variable

# %%
# for this example we will only take one variable in the weather's dataset
list_col_value_weather = ["vit_100"]
df_all = pd.merge(df_all,df_meteo[["Date"]+list_col_value_weather],on="Date",how="left")

# %% [markdown]
# #### we keep only value after 2015_1_3 to avoid missing values

# %%
df_all = df_all[df_all["Date"]>datetime(2015,1,3)].copy()
df_all.sort_values("Date",ascending=1,inplace=True)

# %% [markdown]
# ### MACHINE LEARNING

# %% [markdown]
# #### we create the train/val split
# The objective is now to create a dataset to train a model and a dataset to evaluate our model.

# %%
date_split_val = datetime(2016,1,1)
date_split_test = datetime(2017,1,1)

# %%
df_all_train = df_all[df_all["Date"]<date_split_val]
df_all_val = df_all[(df_all["Date"]>=date_split_val)& (df_all["Date"]<date_split_test)]

# %% [markdown]
# #### for this notebook, we will only use 1 variable in our model

# %%
list_col_model = ["vit_100"]
col_target = "Production_mean_hour"

# %% [markdown]
# #### for this notebook, we will use a linear model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %% [markdown]
# #### we fit the model on the train dataset (2015)

# %%
model.fit(df_all_train[list_col_model],df_all_train[col_target])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #### we predict on the validation dataset (2016)

# %%
list_col_pred_val = list(set(["Date","Eolienne","Production",col_target]+list_col_model))
df_pred_val = df_all_val[list_col_pred_val].copy()

# %%
df_pred_val["pred"] = model.predict(df_all_val[list_col_model])

# %% [markdown]
# #### we evaluate our prediction

# %%
from sklearn.metrics import mean_absolute_error
import numpy as np

# %%
mean_absolute_error(df_pred_val[col_target],df_pred_val["pred"])
# Out:
# 259.41788197686151

# %%
df_pred_val.head()
# Out:
#              Date  Production_mean_hour  Production   vit_100 Eolienne  \
# 63948  2016-01-01            467.763833       631.3  6.848325    Turb5
# 70382  2016-01-01            394.706167       428.5  6.848325    Turb6
# 82776  2016-01-01            432.570000       406.1  6.848325    Turb8
# 140269 2016-01-01            634.161500       924.9  6.848325    Turb2
# 188393 2016-01-01            432.448333       497.2  6.848325   Turb10
#
#               pred
# 63948   510.873332
# 70382   510.873332
# 82776   510.873332
# 140269  510.873332
# 188393  510.873332

# %%
df_pred_val[df_pred_val["Eolienne"]==eolienne_C].set_index("Date")[["Production_mean_hour","pred"]].iloc[0:300].plot(figsize=(16,4))

# %% [markdown]
# #### we predict on the test

# %%
df_all_test = df_all[(df_all["Date"]>=date_split_test)].copy()

# %%
list_col_pred_test = list(set(["Date","Eolienne"]+list_col_model))
df_pred_test = df_all_test[list_col_pred_test].copy()

# %%
df_pred_test["pred"] = model.predict(df_all_test[list_col_model])

# %% [markdown]
# ##### we create the submit_file

# %%
df_pred_test[["Date","Eolienne","pred"]].to_csv("../data/submit_benchmark.csv",sep=";",index=False)

# %%
pd.read_csv("../data/submit_benchmark.csv",sep=";",nrows=5)
# Out:
#                   Date Eolienne        pred
# 0  2017-01-01 00:00:00    Turb1  275.538688
# 1  2017-01-01 00:00:00    Turb8  275.538688
# 2  2017-01-01 00:00:00    Turb3  275.538688
# 3  2017-01-01 00:00:00    Turb4  275.538688
# 4  2017-01-01 00:00:00    Turb7  275.538688

# %% [markdown]
# ### some more data explo

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style='whitegrid', context='notebook')
cols = []

sns.pairplot(df[cols], size=2.5)
plt.tight_layout()
# plt.savefig('./figures/scatter.png', dpi=300)
plt.show()

# %%
# scatter plot production vs wind (to see if it's linear)
